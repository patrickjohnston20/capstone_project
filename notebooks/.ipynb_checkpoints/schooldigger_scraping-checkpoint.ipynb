# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.schooldigger.com/go/TN/schoolrank.aspx'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head id="ctl00_Head1">
#   <meta charset="utf-8"/>
#   <script data-cfasync="false" data-ezscrex="false" data-pagespeed-no-defer="">
# ...

# %%
soup.find('div')
# Out:
# <div class="container-fluid" style="padding-left:0px;padding-right:0px">
# <div class="well well-small" id="navbar">
# <div class="row">
# <div class="col-xs-6 col-sm-4 col-md-7 col-lg-7" id="ctl00_navBar_divLeft">
# <a href="/" style="text-decoration:none">
# <img alt="SchoolDigger.com Logo" class="visible-sm-inline visible-md-inline visible-lg-inline" height="50" id="ctl00_navBar_imgLogo" src="//cdn.schooldigger.com/images/sd2_logo_mono.png" width="220"/>
# <img alt="SchoolDigger.com Logo" class="visible-xs-inline" height="50" id="ctl00_navBar_imgLogoXS" src="//cdn.schooldigger.com/images/sd2_logo_XS.png" width="150"/>
# </a>
# <a class="btn visible-md-inline visible-lg-inline" href="https://www.schooldigger.com/go/TN/search.aspx" id="ctl00_navBar_lnkSearch" role="button">Find a School</a>
# <a class="btn visible-md-inline visible-lg-inline" href="https://www.schooldigger.com/go/TN/schoolrank.aspx" id="ctl00_navBar_lnkRankings" role="button">School Rankings</a>
# </div>
# ...

# %%
soup.find_all('div')
# Out:
# [<div class="container-fluid" style="padding-left:0px;padding-right:0px">
#  <div class="well well-small" id="navbar">
#  <div class="row">
#  <div class="col-xs-6 col-sm-4 col-md-7 col-lg-7" id="ctl00_navBar_divLeft">
#  <a href="/" style="text-decoration:none">
#  <img alt="SchoolDigger.com Logo" class="visible-sm-inline visible-md-inline visible-lg-inline" height="50" id="ctl00_navBar_imgLogo" src="//cdn.schooldigger.com/images/sd2_logo_mono.png" width="220"/>
#  <img alt="SchoolDigger.com Logo" class="visible-xs-inline" height="50" id="ctl00_navBar_imgLogoXS" src="//cdn.schooldigger.com/images/sd2_logo_XS.png" width="150"/>
#  </a>
#  <a class="btn visible-md-inline visible-lg-inline" href="https://www.schooldigger.com/go/TN/search.aspx" id="ctl00_navBar_lnkSearch" role="button">Find a School</a>
#  <a class="btn visible-md-inline visible-lg-inline" href="https://www.schooldigger.com/go/TN/schoolrank.aspx" id="ctl00_navBar_lnkRankings" role="button">School Rankings</a>
#  </div>
# ...
